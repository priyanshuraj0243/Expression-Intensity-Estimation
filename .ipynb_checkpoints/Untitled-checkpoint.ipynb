# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import scipy
import scipy.ndimage

# %%
img_array = cv2.imread("train/angry/Training_3908.jpg")

# %%
img_array.shape
# Out:
# (48, 48, 3)

# %%
print(img_array)
# Out:
# [[[163 163 163]
#   [128 128 128]
#   [114 114 114]
#   ...
#   [139 139 139]
#   [141 141 141]
#   [134 134 134]]
#
#  [[147 147 147]
#   [114 114 114]
#   [102 102 102]
#   ...
#   [142 142 142]
#   [138 138 138]
#   [138 138 138]]
#
#  [[112 112 112]
#   [106 106 106]
#   [ 92  92  92]
#   ...
#   [140 140 140]
#   [141 141 141]
#   [134 134 134]]
#
#  ...
#
#  [[139 139 139]
#   [141 141 141]
#   [136 136 136]
#   ...
#   [154 154 154]
#   [171 171 171]
#   [191 191 191]]
#
#  [[140 140 140]
#   [133 133 133]
#   [120 120 120]
#   ...
#   [138 138 138]
#   [146 146 146]
#   [158 158 158]]
#
#  [[136 136 136]
#   [134 134 134]
#   [113 113 113]
#   ...
#   [146 146 146]
#   [144 144 144]
#   [144 144 144]]]

# %%
plt.imshow(img_array)

# %%
Datadirectory = "train/"

# %%
Classes = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# %%
for category in Classes:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size=224
new_array=cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_array.shape
# Out:
# (224, 224, 3)

# %%
training_Data = []

def create_training_Data():
    for category in Classes:
        path = os.path.join(Datadirectory, category)
        class_num = Classes.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size,img_size))
                training_Data.append([new_array, class_num])
            except Exception as e:
                pass

# %%
create_training_Data()

# %%
print(len(training_Data))
# Out:
# 28709

# %%
import random
random.shuffle(training_Data)

# %%
X = []
y = []

for features,label in training_Data:
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, img_size, img_size, 3)

# %%
print(scipy.__version__)
# Out:
# 1.15.2

# %%
X = []
y = []

for features,label in training_Data:
    X.append(features)
    y.append(label)
    
X = np.array(X, dtype=np.float32).reshape(-1, img_size, img_size, 3)

# %%
X.shape
# Out:
# (28709, 224, 224, 3)

# %%
X = X/255.0;

# %%
y[0]
# Out:
# 3

# %%
type(y)
# Out:
# list

# %%
Y = np.array(y)

# %%
Y.shape
# Out:
# (28709,)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = tf.keras.applications.MobileNetV2()

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
base_input = model.layers[0].input

# %%
base_output = model.layers[-2].output

# %%
base_output
# Out:
# <KerasTensor: shape=(None, 1280) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
final_output = layers.Dense(128)(base_output)
final_output = layers.Activation('relu')(final_output)

# %%
final_output = layers.Dense(128)(base_output)
final_output = layers.Activation('relu')(final_output)

# %%
final_output = layers.Dense(128)(base_output)
final_output = layers.Activation('relu')(final_output)
final_output = layers.Dense(64)(final_output)
final_output = layers.Activation('relu')(final_output)
final_output = layers.Dense(7,activation = 'softmax')(final_output)

# %%
final_output
# Out:
# <KerasTensor: shape=(None, 7) dtype=float32 (created by layer 'dense_9')>

# %%
new_model = keras.Model(inputs = base_input, outputs = final_output)

# %%
new_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
new_model.compile(loss="sparse_categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
import numpy as np

print("X type:", type(X))
print("X dtype:", getattr(X, "dtype", "unknown"))
print("X shape:", getattr(X, "shape", "unknown"))

print("Y type:", type(Y))
print("Y dtype:", getattr(Y, "dtype", "unknown"))
print("Y shape:", getattr(Y, "shape", "unknown"))
# Out:
# X type: <class 'numpy.ndarray'>
# X dtype: float32
# X shape: (28709, 224, 224, 3)
# Y type: <class 'numpy.ndarray'>
# Y dtype: int32
# Y shape: (28709,)

# %%
X = X.astype(np.float32)

# %%
new_model.fit(X, Y, epochs=25, batch_size=4)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 new_model.fit(X, Y, epochs=25, batch_size=4)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the ImageDataGenerator to normalize the images
datagen = ImageDataGenerator(rescale=1./255)

# Define the directory where the images are stored
train_directory = "train/"

# Create the generator for loading images in batches
train_generator = datagen.flow_from_directory(
    train_directory,             # Path to the training dataset folder
    target_size=(224, 224),      # Resize images to 224x224
    batch_size=32,               # Set batch size to a reasonable number (32)
    class_mode='sparse',         # Use sparse categorical labels
    shuffle=True                 # Shuffle the dataset
)

# Now, train the model using the generator
new_model.fit(train_generator, epochs=25)
# Out:
# Found 28709 images belonging to 7 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 19
#      10 train_generator = datagen.flow_from_directory(
#      11     train_directory,             # Path to the training dataset folder
#      12     target_size=(224, 224),      # Resize images to 224x224
#    (...)
#      15     shuffle=True                 # Shuffle the dataset
#      16 )
#      18 # Now, train the model using the generator
# ---> 19 new_model.fit(train_generator, epochs=25)
#
# NameError: name 'new_model' is not defined

# %%
new_model.fit(X,Y, epochs = 25)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 new_model.fit(X,Y, epochs = 25)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ...

# %%
new_model.fit(X, Y, epochs=25, batch_size=32)  # try lowering batch_size
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 new_model.fit(X, Y, epochs=25, batch_size=32)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ...

# %%
X = X.astype(np.float32)

# %%
new_model.fit(X, Y, epochs=25, batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 new_model.fit(X, Y, epochs=25, batch_size=16)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ...

# %%
X = X / 255.0
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 X = X / 255.0
#
# MemoryError: Unable to allocate 16.1 GiB for an array with shape (28709, 224, 224, 3) and data type float32

# %%
X = X.astype(np.float32)
X = X / 255.0  # normalize pixel values
new_model.fit(X, Y, epochs=25, batch_size=16)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    r'C:\Users\rpriy\Desktop\WORKING ON THIS SHIT\8th sem shit\FINAL PROJECT 2\train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse'  # or 'categorical' depending on your labels
)

# %%
new_model.fit(train_generator, epochs=25)

# %%
pip install scipy
# Out:
# ...
#
# ...

# %%
new_model.fit(train_generator, epochs=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 new_model.fit(train_generator, epochs=25)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\preprocessing\image.py:2529, in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2485 @keras_export("keras.preprocessing.image.apply_affine_transform")
#    2486 def apply_affine_transform(
# ...

# %%
# !pip install scipy

# %%
new_model.fit(train_generator, epochs=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 new_model.fit(train_generator, epochs=25)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\preprocessing\image.py:2529, in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2485 @keras_export("keras.preprocessing.image.apply_affine_transform")
#    2486 def apply_affine_transform(
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    r'C:\Users\rpriy\Desktop\WORKING ON THIS SHIT\8th sem shit\FINAL PROJECT 2\train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse'  # or 'categorical' depending on your labels
)
# Out:
# Found 28709 images belonging to 7 classes.

# %%
new_model.fit(train_generator, epochs=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 new_model.fit(train_generator, epochs=25)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\preprocessing\image.py:2529, in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2485 @keras_export("keras.preprocessing.image.apply_affine_transform")
#    2486 def apply_affine_transform(
# ...

# %%
import scipy

# %%
new_model.fit(train_generator, epochs=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 new_model.fit(train_generator, epochs=25)
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\preprocessing\image.py:2529, in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2485 @keras_export("keras.preprocessing.image.apply_affine_transform")
#    2486 def apply_affine_transform(
# ...
