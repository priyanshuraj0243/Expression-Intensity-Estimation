# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPUs detected:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.10.1
# GPUs detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img_array = cv2.imread("train/angry/Training_3908.jpg")

# %%
img_array.shape
# Out:
# (48, 48, 3)

# %%
print(img_array)
# Out:
# [[[163 163 163]
#   [128 128 128]
#   [114 114 114]
#   ...
#   [139 139 139]
#   [141 141 141]
#   [134 134 134]]
#
#  [[147 147 147]
#   [114 114 114]
#   [102 102 102]
#   ...
#   [142 142 142]
#   [138 138 138]
#   [138 138 138]]
#
#  [[112 112 112]
#   [106 106 106]
#   [ 92  92  92]
#   ...
#   [140 140 140]
#   [141 141 141]
#   [134 134 134]]
#
#  ...
#
#  [[139 139 139]
#   [141 141 141]
#   [136 136 136]
#   ...
#   [154 154 154]
#   [171 171 171]
#   [191 191 191]]
#
#  [[140 140 140]
#   [133 133 133]
#   [120 120 120]
#   ...
#   [138 138 138]
#   [146 146 146]
#   [158 158 158]]
#
#  [[136 136 136]
#   [134 134 134]
#   [113 113 113]
#   ...
#   [146 146 146]
#   [144 144 144]
#   [144 144 144]]]

# %%
plt.imshow(img_array)

# %%
Datadirectory = "train/"

# %%
Classes = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# %%
for category in Classes:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size=224
new_array=cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_array.shape
# Out:
# (224, 224, 3)

# %%
training_Data = []

def create_training_Data():
    for category in Classes:
        path = os.path.join(Datadirectory, category)
        class_num = Classes.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size,img_size))
                training_Data.append([new_array, class_num])
            except Exception as e:
                pass

# %%
create_training_Data()

# %%
print(len(training_Data))
# Out:
# 28709

# %%
import random
random.shuffle(training_Data)

# %%
X = []
y = []

for features,label in training_Data:
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, img_size, img_size, 3)

# %%
X.shape
# Out:
# (28709, 224, 224, 3)

# %%
X = X/255.0;

# %%
y[0]
# Out:
# 4

# %%
type(y)
# Out:
# list

# %%
Y = np.array(y)

# %%
Y.shape
# Out:
# (28709,)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = tf.keras.applications.MobileNetV2()

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
base_input = model.layers[0].input

# %%
base_output = model.layers[-2].output

# %%
base_output
# Out:
# <KerasTensor: shape=(None, 1280) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
final_output = layers.Dense(128)(base_output)
final_output - layers.Activation('relu')(final_output)
# Out:
# <KerasTensor: shape=(None, 128) dtype=float32 (created by layer 'tf.math.subtract')>

# %%
final_output = layers.Dense(128)(base_output)
final_output = layers.Activation('relu')(final_output)

# %%
final_output = layers.Dense(128)(base_output)
final_output = layers.Activation('relu')(final_output)
final_output = layers.Dense(64)(final_output)
final_output = layers.Activation('relu')(final_output)
final_output = layers.Dense(7,activation = 'softmax')(final_output)

# %%
final_output
# Out:
# <KerasTensor: shape=(None, 7) dtype=float32 (created by layer 'dense_4')>

# %%
new_model = keras.Model(inputs = base_input, outputs = final_output)

# %%
new_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
new_model.compile(loss="sparse_categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
physical_devices = tf.config.list_physical_devices('GPU')
print(f"Number of GPUs available: {len(physical_devices)}")
# Out:
# Number of GPUs available: 1

# %%
training_Data = []
def create_training_Data():
    count = 0
    for category in Classes:
        path = os.path.join(Datadirectory, category)
        class_num = Classes.index(category)
        for img in os.listdir(path):
            if count >= 50:  # Limit the dataset to 50 images for testing
                break
            try:
                img_array = cv2.imread(os.path.join(path, img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                training_Data.append([new_array, class_num])
                count += 1
            except Exception as e:
                pass
create_training_Data()
print(len(training_Data))
# Out:
# 50

# %%
tf.config.set_visible_devices([], 'GPU')  # Disable GPU and force CPU usage
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 tf.config.set_visible_devices([], 'GPU')
#
# File ~\anaconda3\envs\tf_gpu_env\lib\site-packages\tensorflow\python\framework\config.py:528, in set_visible_devices(devices, device_type)
#     495 @tf_export('config.set_visible_devices',
#     496            'config.experimental.set_visible_devices')
#     497 @deprecation.deprecated_endpoints('config.experimental.set_visible_devices')
#     498 def set_visible_devices(devices, device_type=None):
#     499   """Set the list of visible devices.
#     500
#     501   Specifies which `PhysicalDevice` objects are visible to the runtime.
#    (...)
#     526     RuntimeError: Runtime is already initialized.
#     527   """
# --> 528   context.context().set_visible_devices(devices, device_type)
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2

# Path to your training dataset
train_directory = "train/"
img_size = 224
batch_size = 32

# Create the data generator
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    directory=train_directory,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='sparse',  # because labels are integers 0–6
    shuffle=True
)
# Out:
# Found 28709 images belonging to 7 classes.

# %%
# Load base model
base_model = MobileNetV2(include_top=False, input_shape=(img_size, img_size, 3), pooling='avg', weights='imagenet')
base_model.trainable = False  # Freeze base model initially

# Add custom layers on top
x = layers.Dense(128, activation='relu')(base_model.output)
x = layers.Dense(64, activation='relu')(x)
output = layers.Dense(7, activation='softmax')(x)

# Final model
new_model = models.Model(inputs=base_model.input, outputs=output)
new_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
new_model.summary()
# Out:
# ...
# 9406464/9406464 [==============================] - 0s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_2[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
# ...

# %%
# Train using generator
history = new_model.fit(
    train_generator,
    epochs=25
)
# Out:
# Epoch 1/25
# 898/898 [==============================] - 235s 247ms/step - loss: 1.5217 - accuracy: 0.4122
# Epoch 2/25
# 898/898 [==============================] - 43s 48ms/step - loss: 1.3844 - accuracy: 0.4687
# Epoch 3/25
# 898/898 [==============================] - 43s 48ms/step - loss: 1.3343 - accuracy: 0.4897
# Epoch 4/25
# 898/898 [==============================] - 43s 48ms/step - loss: 1.2931 - accuracy: 0.5066
# Epoch 5/25
# 898/898 [==============================] - 43s 48ms/step - loss: 1.2629 - accuracy: 0.5206
# Epoch 6/25
# 898/898 [==============================] - 44s 49ms/step - loss: 1.2291 - accuracy: 0.5339
# Epoch 7/25
# 898/898 [==============================] - 43s 48ms/step - loss: 1.2043 - accuracy: 0.5432
# Epoch 8/25
# 898/898 [==============================] - 43s 48ms/step - loss: 1.1758 - accuracy: 0.5544
# Epoch 9/25
# 898/898 [==============================] - 43s 48ms/step - loss: 1.1540 - accuracy: 0.5636
# Epoch 10/25
# ...

# %%
new_model.save("emotion_model.h5")  # You can change the name if you want

# %%
from tensorflow.keras.models import load_model

model = load_model("emotion_model.h5")

# %%
frame = cv2.imread("happyboy.jpg")

# %%
frame.shape
# Out:
# (200, 357, 3)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
 faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (200, 357)

# %%
faces = faceCascade.detectMultiScale(gray,1.1,4)

# %%
faces = faceCascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in faces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = frame[y:y+h, x:x+w]
    cv2.rectangle(frame, (x,y), (x+w, y+h), (255,0,0),2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if len(facess) == 0:
        print("Face not detected")
    else:
        for (ex,ey,ew,eh) in facess:
            face_roi = roi_color[ey: ey+eh, ex:ex+ew]

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(face_roi, cv2.COLOR_BGR2RGB))

# %%
final_image = cv2.resize(face_roi, (224, 224))
final_image = np.expand_dims(final_image,axis  = 0)
final_image = final_image/255.0

# %%
Predictions = new_model.predict(final_image)
# Out:
# 1/1 [==============================] - 1s 723ms/step

# %%
Predictions[0]
# Out:
# array([1.3755173e-04, 4.2346183e-13, 1.8437109e-10, 9.9986219e-01,
#        5.8657810e-12, 2.9146526e-07, 2.3819045e-15], dtype=float32)

# %%
np.argmax(Predictions)
# Out:
# 3

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load your trained model
model = load_model("emotion_model.h5")

# Define class labels
class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Initialize webcam
cap = cv2.VideoCapture(0)  # 0 for default webcam

# Load Haar Cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

img_size = 224  # Make sure this matches your model input size

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Convert to grayscale (for face detection)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in frame
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        # Draw rectangle around face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # Extract face region of interest (ROI)
        face_roi = frame[y:y+h, x:x+w]
        face_roi = cv2.resize(face_roi, (img_size, img_size))
        face_roi = face_roi / 255.0
        face_roi = np.expand_dims(face_roi, axis=0)

        # Predict emotion
        predictions = model.predict(face_roi)
        emotion_index = np.argmax(predictions)
        emotion_label = class_names[emotion_index]

        # Display emotion label
        cv2.putText(frame, emotion_label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX,
                    0.9, (255, 255, 255), 2)

    # Show the frame
    cv2.imshow('Real-time Emotion Detection', frame)

    # Break loop with 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step

# %%
import datetime

# Inside your face loop
timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
log_line = f"{timestamp}, Face {emotion_index}, Emotion: {emotion_label}\n"
with open("emotion_log.txt", "a") as f:
    f.write(log_line)

# %%
# Get frame width & height
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))

# Define VideoWriter to save output
out = cv2.VideoWriter('output_with_emotions.avi',
                      cv2.VideoWriter_fourcc(*'XVID'),
                      10, (frame_width, frame_height))

# %%
out.write(frame)  # Save the frame with overlay

# %%
out.release()  # Release video writer

# %%
confidence = np.max(predictions)
label = f"{emotion_label} ({confidence*100:.1f}%)"

cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX,
            0.9, (255, 255, 255), 2)
# Out:
# array([[[18, 23, 22],
#         [18, 23, 21],
#         [18, 23, 20],
#         ...,
#         [24, 26, 26],
#         [22, 25, 24],
#         [22, 25, 24]],
#
#        [[20, 22, 22],
#         [20, 22, 22],
#         [21, 23, 23],
#         ...,
#         [20, 25, 24],
#         [20, 25, 24],
#         [19, 24, 23]],
#
#        [[19, 21, 21],
#         [21, 22, 22],
#         [22, 22, 22],
#         ...,
#         [20, 25, 24],
#         [19, 24, 23],
#         [19, 24, 23]],
#
#        ...,
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [16, 16, 16],
#         [16, 16, 16],
#         [16, 16, 16]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [17, 18, 17],
#         [16, 17, 15],
#         [16, 17, 15]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [16, 17, 15],
#         [16, 17, 15],
#         [16, 17, 15]]], dtype=uint8)

# %%
import os
os.makedirs("detected_faces", exist_ok=True)

# %%
face_filename = f"face_{emotion_label}_{timestamp.replace(':', '-')}.jpg"
cv2.imwrite(f"detected_faces/{face_filename}", face_roi[0]*255.0)
# Out:
# True
